# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ============================================================
# Chapter 01: The Machine Learning Landscape
# Book: Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow
# Author: Aurélien Géron (O'Reilly)
#
# Author (Student):
# Auldy Ranayu Sanny Prahasty Rachman
#
# Individual Enrichment Assignment
# ============================================================

# INTRODUCTION
# Chapter ini memperkenalkan konsep dasar Machine Learning,
# termasuk definisi, alasan penggunaan, jenis sistem ML,
# serta tantangan utama dalam pengembangan model.

# WHAT IS MACHINE LEARNING?
# Machine Learning memungkinkan sistem komputer
# belajar dari data tanpa aturan eksplisit.

# WHY MACHINE LEARNING?
# Digunakan ketika masalah terlalu kompleks,
# data berubah, dan aturan manual tidak efektif.

# TYPES OF MACHINE LEARNING
# - Supervised Learning
# - Unsupervised Learning
# - Semi-Supervised Learning
# - Reinforcement Learning

# BATCH VS ONLINE LEARNING
# Batch learning menggunakan seluruh data sekaligus.
# Online learning belajar secara bertahap.

# INSTANCE VS MODEL BASED LEARNING
# Instance-based menyimpan data.
# Model-based membangun model matematis.

# SIMPLE MODEL-BASED EXAMPLE
import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array([[20000], [30000], [40000], [50000]])
y = np.array([5.5, 6.5, 7.2, 7.8])

model = LinearRegression()
model.fit(X, y)

prediction = model.predict([[35000]])
print("Prediksi tingkat kepuasan hidup:", prediction)

# CHALLENGES IN MACHINE LEARNING
# - Data tidak cukup
# - Overfitting
# - Underfitting

# NO FREE LUNCH THEOREM
# Tidak ada algoritma terbaik untuk semua masalah.

# CONCLUSION
# Chapter ini menjadi dasar untuk memahami
# proses Machine Learning pada bab selanjutnya.
# Out:
# Prediksi tingkat kepuasan hidup: [6.75]
